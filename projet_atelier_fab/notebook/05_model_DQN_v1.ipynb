# %%
# cellule 1 : import et verification de la version

import gymnasium as gym
gym.__version__
# Out:
# '1.2.2'

# %%
# cellule 2 : test de l'environnement

from workshop_env import WorkshopEnv

env = WorkshopEnv()
obs, info = env.reset()
obs
# Out:
# array([ 0.,  0.,  0.,  0.,  0., 10.,  0.,  0.,  0.,  0.,  0.,  0.],
#       dtype=float32)

# %%
obs, reward, done, truncated, info = env.step(200)  # action = attendre
obs
# Out:
# array([ 1.,  0.,  0.,  0.,  0., 10.,  0.,  0.,  0.,  0.,  0.,  0.],
#       dtype=float32)

# %%
obs, reward, done, truncated, info = env.step(0)   # produire 1 P1
obs
# Out:
# array([2., 1., 2., 0., 0., 9., 0., 0., 0., 0., 0., 0.], dtype=float32)

# %%
obs, reward, done, truncated, info = env.step(150) # commander 1 MP
obs
# Out:
# array([3., 1., 1., 0., 0., 9., 0., 0., 0., 0., 0., 0.], dtype=float32)

# %%
obs, reward, done, truncated, info = env.step(200) # attendre
obs
# Out:
# array([4., 0., 0., 0., 0., 9., 1., 0., 0., 0., 0., 0.], dtype=float32)

# %%
env = WorkshopEnv()
obs, info = env.reset()

obs
# Out:
# array([ 0.,  0.,  0.,  0.,  0., 10.,  0.,  0.,  0.,  0.,  0.,  0.],
#       dtype=float32)

# %%
env.step(0)   # produire 1 P1
# Out:
# (array([1., 1., 2., 0., 0., 9., 0., 0., 0., 0., 0., 0.], dtype=float32),
#  0,
#  False,
#  False,
#  {})

# %%
env = WorkshopEnv()
obs, info = env.reset()
env.step(0)  # produire 1 P1
# Out:
# (array([1., 1., 2., 0., 0., 9., 0., 0., 0., 0., 0., 0.], dtype=float32),
#  0,
#  False,
#  False,
#  {})
