# %%
# Cellule 1 – Imports de base 

import numpy as np

from env.workshop_env import WorkshopEnv

# %%
# Cellule 2 – Créer l’env et afficher un état

env = WorkshopEnv()

obs, info = env.reset()
print("Shape observation :", obs.shape)
print("Première observation :", obs)
print("Action space :", env.action_space)
print("Observation space :", env.observation_space)
# Out:
# Shape observation : (13,)
# Première observation : [ 0.  0.  0.  0.  0. 10.  0.  0.  0.  0.  0.  0.  0.]
# Action space : Discrete(201)
# Observation space : Box(0.0, [1.008e+04 1.000e+00 1.000e+02 1.000e+00 1.000e+02 5.000e+01 5.000e+01
#  5.000e+01 5.000e+01 1.008e+04 1.000e+03 1.000e+03 1.000e+03], (13,), float32)

# %%
# Cellule 3 – Épisode avec actions aléatoires
# Objectif : vérifier que l’atelier ne plante pas sur 7 jours et voir un total de reward.
# On doit avoir environ 10080 steps si tout est cohérent.

env = WorkshopEnv()
obs, info = env.reset()

done = False
total_reward = 0.0
step = 0

while not done:
    action = env.action_space.sample()  # politique purement aléatoire
    obs, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    step += 1

    done = terminated or truncated

print("Nombre de steps :", step)
print("Reward total sur la semaine (policy aléatoire) :", total_reward)
# Out:
# Nombre de steps : 10080
# Reward total sur la semaine (policy aléatoire) : -49009.95999999999

# %%
# Cellule 4 – Imports SB3 et check_env

# Etape 3 – Brancher Stable-Baselines3 (DQN)
# On va utiliser SB3 pour éviter de recoder tout le DQN 
#(réseau Q, replay buffer, target network, etc.) à la main.

from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
# Cellule 5 – Vérifier l’environnement avec check_env

# si pas d'affichage, l'environnement respecte bien l’API Gymnasium
env = WorkshopEnv()
check_env(env, warn=True)

# %%
# Cellule 6 : vectorisation de l'environnement
# avec DummyVecEnv

from env.workshop_env import WorkshopEnv
from stable_baselines3.common.vec_env import DummyVecEnv

def make_env():
    # Chaque appel crée un nouvel atelier propre (reset complet)
    return WorkshopEnv()

# Environnement vectorisé avec 1 seul atelier
vec_env = DummyVecEnv([make_env])

vec_env

# %%
# Cellule 7 : test

obs = vec_env.reset()
print("Observation depuis vec_env :", obs)
print("Shape :", obs.shape)

# une action aléatoire pour tester
action = [vec_env.action_space.sample()]  # liste de taille 1
obs, reward, done, info = vec_env.step(action)
print("Après un step :")
print("obs :", obs)
print("reward :", reward)
print("done :", done)
# Out:
# Observation depuis vec_env : [[ 0.  0.  0.  0.  0. 10.  0.  0.  0.  0.  0.  0.  0.]]
# Shape : (1, 13)
# Après un step :
# obs : [[ 1.  0.  0.  0.  0. 10.  0.  0.  0.  0.  0.  0.  0.]]
# reward : [-1.]
# done : [False]

# %%
# Cellule 8 : construction du DQN

from stable_baselines3 import DQN

model = DQN(
    "MlpPolicy",          # Réseau fully-connected (adapté à un vecteur de 13 features)
    vec_env,              # Ton environnement vectorisé
    learning_rate=1e-4,   # Pas d’apprentissage : petit pour éviter l’instabilité
    buffer_size=100_000,  # Taille de la mémoire d’expérience
    learning_starts=5_000,# Avant 5000 interactions, il explore uniquement
    batch_size=256,       # Taille des minibatches
    gamma=0.995,          # Discount factor : horizon long → gamma élevé
    train_freq=4,         # Mise à jour du réseau toutes les 4 steps
    target_update_interval=5_000, # Mise à jour du target-network
    verbose=1             # Afficher les logs
)

model
# Out:
# Using cpu device

# %%
# Cellule 9 : entrainement

total_timesteps = 300_000 

model.learn(
    total_timesteps=total_timesteps,
    progress_bar=True  # si ta version de SB3 le supporte
)

model.save("dqn_workshop_v1")
# Out:
# C:\Users\fabri\anaconda3\envs\qlearning\lib\site-packages\rich\live.py:256: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 503      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 40320    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.68     |
# |    n_updates        | 8829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 451      |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 80640    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.55     |
# |    n_updates        | 18909    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 436      |
# |    time_elapsed     | 277      |
# |    total_timesteps  | 120960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.13     |
# |    n_updates        | 28989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 425      |
# |    time_elapsed     | 379      |
# |    total_timesteps  | 161280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.37     |
# |    n_updates        | 39069    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 416      |
# |    time_elapsed     | 483      |
# |    total_timesteps  | 201600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.16     |
# |    n_updates        | 49149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 412      |
# |    time_elapsed     | 587      |
# |    total_timesteps  | 241920   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71     |
# |    n_updates        | 59229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 410      |
# |    time_elapsed     | 687      |
# |    total_timesteps  | 282240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.59     |
# |    n_updates        | 69309    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# Cellule 10 : test sur une semaine

env_test = WorkshopEnv()
obs, info = env_test.reset()

done = False
total_reward = 0
step = 0

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env_test.step(int(action))
    total_reward += reward
    step += 1
    done = terminated or truncated

print("Steps exécutés :", step)
print("Reward total du DQN sur une semaine :", total_reward)
# Out:
# Steps exécutés : 10080
# Reward total du DQN sur une semaine : -13963.279999999995

# %%
env_debug = WorkshopEnv()
obs, info = env_debug.reset()

total_reward = 0

for t in range(1000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env_debug.step(int(action))

    total_reward += reward

    print(
        f"t={t:03d}, action={int(action)}, "
        f"reward={reward:.2f}, total={total_reward:.2f}, "
        f"time={env_debug.time}, raw={env_debug.stock.raw}, "
        f"P1={env_debug.stock.p1}, P2_inter={env_debug.stock.p2_inter}, "
        f"P2={env_debug.stock.p2}, backlog1={env_debug.demande_p1}, "
        f"backlog2={env_debug.demande_p2}, "
        f"busyM1={env_debug.m1.busy}, busyM2={env_debug.m2.busy}"
    )

    if terminated or truncated:
        break
# Out:
# t=000, action=150, reward=-1.00, total=-1.00, time=1, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=001, action=123, reward=-1.00, total=-2.00, time=2, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=002, action=123, reward=-1.00, total=-3.00, time=3, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=003, action=123, reward=-1.00, total=-4.00, time=4, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=004, action=123, reward=-1.00, total=-5.00, time=5, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=005, action=123, reward=-1.00, total=-6.00, time=6, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=006, action=123, reward=-1.00, total=-7.00, time=7, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=007, action=123, reward=-1.00, total=-8.00, time=8, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=008, action=123, reward=-1.00, total=-9.00, time=9, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=009, action=123, reward=-1.00, total=-10.00, time=10, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=010, action=123, reward=-1.00, total=-11.00, time=11, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=011, action=123, reward=-1.00, total=-12.00, time=12, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=012, action=123, reward=-1.00, total=-13.00, time=13, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=013, action=123, reward=-1.00, total=-14.00, time=14, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=014, action=123, reward=-1.02, total=-15.02, time=15, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=015, action=123, reward=-1.00, total=-16.02, time=16, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=016, action=123, reward=-1.00, total=-17.02, time=17, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=017, action=123, reward=-1.00, total=-18.02, time=18, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=018, action=123, reward=-1.00, total=-19.02, time=19, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=019, action=123, reward=-1.00, total=-20.02, time=20, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=020, action=123, reward=-1.00, total=-21.02, time=21, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=021, action=123, reward=-1.00, total=-22.02, time=22, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=022, action=123, reward=-1.00, total=-23.02, time=23, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=023, action=123, reward=-1.00, total=-24.02, time=24, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=024, action=123, reward=-1.00, total=-25.02, time=25, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=025, action=123, reward=-1.00, total=-26.02, time=26, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=026, action=123, reward=-1.00, total=-27.02, time=27, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=027, action=123, reward=-1.00, total=-28.02, time=28, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=028, action=123, reward=-1.00, total=-29.02, time=29, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=False
# t=029, action=123, reward=-1.04, total=-30.06, time=30, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=030, action=123, reward=-1.00, total=-31.06, time=31, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=031, action=123, reward=-1.00, total=-32.06, time=32, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=032, action=123, reward=-1.00, total=-33.06, time=33, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=033, action=123, reward=-1.00, total=-34.06, time=34, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=034, action=123, reward=-1.00, total=-35.06, time=35, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=035, action=123, reward=-1.00, total=-36.06, time=36, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=036, action=123, reward=-1.00, total=-37.06, time=37, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=037, action=123, reward=-1.00, total=-38.06, time=38, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=038, action=123, reward=-1.00, total=-39.06, time=39, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=039, action=123, reward=-1.00, total=-40.06, time=40, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=040, action=123, reward=-1.00, total=-41.06, time=41, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=041, action=123, reward=-1.00, total=-42.06, time=42, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=042, action=123, reward=-1.00, total=-43.06, time=43, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=043, action=123, reward=-1.00, total=-44.06, time=44, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=2, busyM1=False, busyM2=False
# t=044, action=123, reward=-1.06, total=-45.12, time=45, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=045, action=123, reward=-1.00, total=-46.12, time=46, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=046, action=73, reward=-1.00, total=-47.12, time=47, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=047, action=73, reward=-1.00, total=-48.12, time=48, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=048, action=73, reward=-1.00, total=-49.12, time=49, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=049, action=73, reward=-1.00, total=-50.12, time=50, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=050, action=73, reward=-1.00, total=-51.12, time=51, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=051, action=73, reward=-1.00, total=-52.12, time=52, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=052, action=73, reward=-1.00, total=-53.12, time=53, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=053, action=73, reward=-1.00, total=-54.12, time=54, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=054, action=73, reward=-1.00, total=-55.12, time=55, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=055, action=73, reward=-1.00, total=-56.12, time=56, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=056, action=73, reward=-1.00, total=-57.12, time=57, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=057, action=73, reward=-1.00, total=-58.12, time=58, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=058, action=73, reward=-1.00, total=-59.12, time=59, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=059, action=73, reward=-1.06, total=-60.18, time=60, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=060, action=73, reward=-1.00, total=-61.18, time=61, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=061, action=73, reward=-1.00, total=-62.18, time=62, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=062, action=73, reward=-1.00, total=-63.18, time=63, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=063, action=73, reward=-1.00, total=-64.18, time=64, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=064, action=73, reward=-1.00, total=-65.18, time=65, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=065, action=73, reward=-1.00, total=-66.18, time=66, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=066, action=73, reward=-1.00, total=-67.18, time=67, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=067, action=73, reward=-1.00, total=-68.18, time=68, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=068, action=73, reward=-1.00, total=-69.18, time=69, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=069, action=73, reward=-1.00, total=-70.18, time=70, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=070, action=73, reward=-1.00, total=-71.18, time=71, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=071, action=73, reward=-1.00, total=-72.18, time=72, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=072, action=73, reward=-1.00, total=-73.18, time=73, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=073, action=73, reward=-1.00, total=-74.18, time=74, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=074, action=73, reward=-1.06, total=-75.24, time=75, raw=10, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=False
# t=075, action=55, reward=30.00, total=-45.24, time=76, raw=4, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=076, action=72, reward=-1.00, total=-46.24, time=77, raw=4, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=077, action=72, reward=-1.00, total=-47.24, time=78, raw=4, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=078, action=72, reward=-1.00, total=-48.24, time=79, raw=4, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=079, action=72, reward=-1.00, total=-49.24, time=80, raw=4, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=080, action=28, reward=-1.00, total=-50.24, time=81, raw=4, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=081, action=28, reward=-1.00, total=-51.24, time=82, raw=4, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=082, action=28, reward=-1.00, total=-52.24, time=83, raw=4, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=083, action=95, reward=-1.00, total=-53.24, time=84, raw=4, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=084, action=95, reward=-1.00, total=-54.24, time=85, raw=4, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=085, action=95, reward=-1.00, total=-55.24, time=86, raw=4, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=086, action=95, reward=-1.00, total=-56.24, time=87, raw=4, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=087, action=95, reward=-1.00, total=-57.24, time=88, raw=4, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=088, action=53, reward=-1.00, total=-58.24, time=89, raw=4, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=089, action=53, reward=-1.06, total=-59.30, time=90, raw=4, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=090, action=53, reward=-1.00, total=-60.30, time=91, raw=4, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=091, action=53, reward=-1.00, total=-61.30, time=92, raw=4, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=092, action=53, reward=-1.00, total=-62.30, time=93, raw=4, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=093, action=53, reward=-1.00, total=-63.30, time=94, raw=4, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=094, action=74, reward=-1.00, total=-64.30, time=95, raw=4, P1=0, P2_inter=2, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=095, action=104, reward=-1.00, total=-65.30, time=96, raw=4, P1=0, P2_inter=2, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=096, action=72, reward=-1.00, total=-66.30, time=97, raw=4, P1=0, P2_inter=2, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=097, action=84, reward=-1.00, total=-67.30, time=98, raw=4, P1=0, P2_inter=2, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=098, action=84, reward=-1.00, total=-68.30, time=99, raw=4, P1=0, P2_inter=2, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=099, action=84, reward=-1.00, total=-69.30, time=100, raw=4, P1=0, P2_inter=2, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=100, action=200, reward=-0.20, total=-69.50, time=101, raw=4, P1=0, P2_inter=2, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=101, action=200, reward=-0.20, total=-69.70, time=102, raw=4, P1=0, P2_inter=2, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=102, action=200, reward=-0.20, total=-69.90, time=103, raw=4, P1=0, P2_inter=2, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=103, action=200, reward=-0.20, total=-70.10, time=104, raw=4, P1=0, P2_inter=2, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=104, action=200, reward=-0.26, total=-70.36, time=105, raw=4, P1=0, P2_inter=3, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=105, action=84, reward=-1.00, total=-71.36, time=106, raw=4, P1=0, P2_inter=3, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=106, action=84, reward=-1.00, total=-72.36, time=107, raw=4, P1=0, P2_inter=3, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=107, action=84, reward=-1.00, total=-73.36, time=108, raw=4, P1=0, P2_inter=3, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=108, action=200, reward=-0.20, total=-73.56, time=109, raw=4, P1=0, P2_inter=3, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=109, action=200, reward=-0.20, total=-73.76, time=110, raw=4, P1=0, P2_inter=3, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=110, action=200, reward=-0.20, total=-73.96, time=111, raw=4, P1=0, P2_inter=3, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=111, action=200, reward=-0.20, total=-74.16, time=112, raw=4, P1=0, P2_inter=3, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=112, action=200, reward=-0.20, total=-74.36, time=113, raw=4, P1=0, P2_inter=3, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=113, action=200, reward=-0.20, total=-74.56, time=114, raw=4, P1=0, P2_inter=3, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=114, action=200, reward=-0.20, total=-74.76, time=115, raw=4, P1=0, P2_inter=4, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=115, action=99, reward=-1.00, total=-75.76, time=116, raw=4, P1=0, P2_inter=4, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=116, action=99, reward=-1.00, total=-76.76, time=117, raw=4, P1=0, P2_inter=4, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=117, action=99, reward=-1.00, total=-77.76, time=118, raw=4, P1=0, P2_inter=4, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=118, action=200, reward=-0.20, total=-77.96, time=119, raw=5, P1=0, P2_inter=4, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=119, action=99, reward=-1.06, total=-79.02, time=120, raw=5, P1=0, P2_inter=4, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=120, action=99, reward=-1.00, total=-80.02, time=121, raw=5, P1=0, P2_inter=4, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=121, action=200, reward=-0.20, total=-80.22, time=122, raw=5, P1=0, P2_inter=4, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=122, action=200, reward=-0.20, total=-80.42, time=123, raw=5, P1=0, P2_inter=4, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=123, action=200, reward=-0.20, total=-80.62, time=124, raw=5, P1=0, P2_inter=4, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=124, action=200, reward=-0.20, total=-80.82, time=125, raw=5, P1=0, P2_inter=5, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=125, action=140, reward=-1.00, total=-81.82, time=126, raw=5, P1=0, P2_inter=5, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=126, action=140, reward=-1.00, total=-82.82, time=127, raw=5, P1=0, P2_inter=5, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=False
# t=127, action=104, reward=75.00, total=-7.82, time=128, raw=5, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=True
# t=128, action=73, reward=-1.00, total=-8.82, time=129, raw=5, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=True
# t=129, action=73, reward=-1.00, total=-9.82, time=130, raw=5, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=True
# t=130, action=73, reward=-1.00, total=-10.82, time=131, raw=5, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=True
# t=131, action=73, reward=-1.00, total=-11.82, time=132, raw=5, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=True
# t=132, action=73, reward=-1.00, total=-12.82, time=133, raw=5, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=True
# t=133, action=73, reward=-1.00, total=-13.82, time=134, raw=5, P1=0, P2_inter=0, P2=0, backlog1=0, backlog2=3, busyM1=True, busyM2=True
# t=134, action=73, reward=-1.06, total=-14.88, time=135, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=135, action=73, reward=-1.00, total=-15.88, time=136, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=136, action=73, reward=-1.00, total=-16.88, time=137, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=137, action=73, reward=-1.00, total=-17.88, time=138, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=138, action=73, reward=-1.00, total=-18.88, time=139, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=139, action=73, reward=-1.00, total=-19.88, time=140, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=140, action=143, reward=-1.00, total=-20.88, time=141, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=141, action=143, reward=-1.00, total=-21.88, time=142, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=142, action=143, reward=-1.00, total=-22.88, time=143, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=143, action=73, reward=-1.00, total=-23.88, time=144, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=144, action=73, reward=-1.00, total=-24.88, time=145, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=145, action=73, reward=-1.00, total=-25.88, time=146, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=146, action=73, reward=-1.00, total=-26.88, time=147, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=147, action=73, reward=-1.00, total=-27.88, time=148, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=148, action=73, reward=-1.00, total=-28.88, time=149, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=149, action=73, reward=18.94, total=-9.94, time=150, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=150, action=73, reward=-1.00, total=-10.94, time=151, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=151, action=73, reward=-1.00, total=-11.94, time=152, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=152, action=73, reward=-1.00, total=-12.94, time=153, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=153, action=11, reward=-1.00, total=-13.94, time=154, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=154, action=11, reward=-1.00, total=-14.94, time=155, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=155, action=11, reward=-1.00, total=-15.94, time=156, raw=5, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=156, action=11, reward=-1.00, total=-16.94, time=157, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=157, action=11, reward=-1.00, total=-17.94, time=158, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=158, action=61, reward=-1.00, total=-18.94, time=159, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=159, action=61, reward=-1.00, total=-19.94, time=160, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=160, action=61, reward=-1.00, total=-20.94, time=161, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=161, action=61, reward=-1.00, total=-21.94, time=162, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=162, action=61, reward=-1.00, total=-22.94, time=163, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=163, action=61, reward=-1.00, total=-23.94, time=164, raw=5, P1=0, P2_inter=1, P2=1, backlog1=0, backlog2=3, busyM1=False, busyM2=True
# t=164, action=4, reward=22.46, total=-1.48, time=165, raw=0, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=165, action=4, reward=-1.00, total=-2.48, time=166, raw=0, P1=0, P2_inter=1, P2=0, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=166, action=4, reward=-1.00, total=-3.48, time=167, raw=0, P1=1, P2_inter=1, P2=0, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=167, action=4, reward=-1.00, total=-4.48, time=168, raw=0, P1=1, P2_inter=1, P2=0, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=168, action=4, reward=-1.00, total=-5.48, time=169, raw=0, P1=1, P2_inter=1, P2=0, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=169, action=4, reward=-1.00, total=-6.48, time=170, raw=0, P1=2, P2_inter=1, P2=0, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=170, action=4, reward=-1.00, total=-7.48, time=171, raw=0, P1=2, P2_inter=1, P2=0, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=171, action=4, reward=-1.00, total=-8.48, time=172, raw=0, P1=2, P2_inter=1, P2=1, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=172, action=4, reward=-1.00, total=-9.48, time=173, raw=0, P1=3, P2_inter=1, P2=1, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=173, action=4, reward=-1.00, total=-10.48, time=174, raw=0, P1=3, P2_inter=1, P2=1, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=174, action=4, reward=-1.00, total=-11.48, time=175, raw=0, P1=3, P2_inter=1, P2=1, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=175, action=4, reward=-1.00, total=-12.48, time=176, raw=0, P1=4, P2_inter=1, P2=1, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=176, action=4, reward=-1.00, total=-13.48, time=177, raw=0, P1=4, P2_inter=1, P2=1, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=177, action=4, reward=-1.00, total=-14.48, time=178, raw=0, P1=4, P2_inter=1, P2=1, backlog1=0, backlog2=2, busyM1=True, busyM2=True
# t=178, action=4, reward=-1.00, total=-15.48, time=179, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=2, busyM1=False, busyM2=True
# t=179, action=4, reward=18.98, total=3.50, time=180, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=180, action=4, reward=-1.00, total=2.50, time=181, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=181, action=4, reward=-1.00, total=1.50, time=182, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=182, action=4, reward=-1.00, total=0.50, time=183, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=183, action=4, reward=-1.00, total=-0.50, time=184, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=184, action=4, reward=-1.00, total=-1.50, time=185, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=185, action=4, reward=-1.00, total=-2.50, time=186, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=186, action=4, reward=-1.00, total=-3.50, time=187, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=187, action=4, reward=-1.00, total=-4.50, time=188, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=188, action=4, reward=-1.00, total=-5.50, time=189, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=189, action=4, reward=-1.00, total=-6.50, time=190, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=190, action=4, reward=-1.00, total=-7.50, time=191, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=191, action=4, reward=-1.00, total=-8.50, time=192, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=192, action=4, reward=-1.00, total=-9.50, time=193, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=193, action=4, reward=-1.00, total=-10.50, time=194, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=1, busyM1=False, busyM2=True
# t=194, action=4, reward=19.00, total=8.50, time=195, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=True
# t=195, action=4, reward=-1.00, total=7.50, time=196, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=True
# t=196, action=4, reward=-1.00, total=6.50, time=197, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=True
# t=197, action=4, reward=-1.00, total=5.50, time=198, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=True
# t=198, action=4, reward=-1.00, total=4.50, time=199, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=True
# t=199, action=4, reward=-1.00, total=3.50, time=200, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=True
# t=200, action=4, reward=-1.00, total=2.50, time=201, raw=0, P1=5, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=True
# t=201, action=4, reward=-1.00, total=1.50, time=202, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=202, action=4, reward=-1.00, total=0.50, time=203, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=203, action=4, reward=-1.00, total=-0.50, time=204, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=204, action=4, reward=-1.00, total=-1.50, time=205, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=205, action=4, reward=-1.00, total=-2.50, time=206, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=206, action=4, reward=-1.00, total=-3.50, time=207, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=207, action=4, reward=-1.00, total=-4.50, time=208, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=208, action=4, reward=-1.00, total=-5.50, time=209, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=209, action=4, reward=-1.00, total=-6.50, time=210, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=210, action=4, reward=-1.00, total=-7.50, time=211, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=211, action=4, reward=-1.00, total=-8.50, time=212, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=212, action=4, reward=-1.00, total=-9.50, time=213, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=213, action=4, reward=-1.00, total=-10.50, time=214, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=214, action=4, reward=-1.00, total=-11.50, time=215, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=215, action=4, reward=-1.00, total=-12.50, time=216, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=216, action=4, reward=-1.00, total=-13.50, time=217, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=217, action=4, reward=-1.00, total=-14.50, time=218, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=218, action=4, reward=-1.00, total=-15.50, time=219, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=219, action=4, reward=-1.00, total=-16.50, time=220, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=220, action=4, reward=-1.00, total=-17.50, time=221, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=221, action=4, reward=-1.00, total=-18.50, time=222, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=222, action=4, reward=-1.00, total=-19.50, time=223, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=223, action=4, reward=-1.00, total=-20.50, time=224, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=224, action=4, reward=-1.00, total=-21.50, time=225, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=225, action=4, reward=-1.00, total=-22.50, time=226, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=226, action=4, reward=-1.00, total=-23.50, time=227, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=227, action=4, reward=-1.00, total=-24.50, time=228, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=228, action=4, reward=-1.00, total=-25.50, time=229, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=229, action=4, reward=-1.00, total=-26.50, time=230, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=230, action=4, reward=-1.00, total=-27.50, time=231, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=231, action=4, reward=-1.00, total=-28.50, time=232, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=232, action=4, reward=-1.00, total=-29.50, time=233, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=233, action=4, reward=-1.00, total=-30.50, time=234, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=234, action=4, reward=-1.00, total=-31.50, time=235, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=235, action=4, reward=-1.00, total=-32.50, time=236, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=236, action=4, reward=-1.00, total=-33.50, time=237, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=237, action=4, reward=-1.00, total=-34.50, time=238, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=238, action=4, reward=-1.00, total=-35.50, time=239, raw=0, P1=5, P2_inter=1, P2=1, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=239, action=4, reward=21.00, total=-14.50, time=240, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=240, action=4, reward=-1.00, total=-15.50, time=241, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=241, action=4, reward=-1.00, total=-16.50, time=242, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=242, action=4, reward=-1.00, total=-17.50, time=243, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=243, action=4, reward=-1.00, total=-18.50, time=244, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=244, action=4, reward=-1.00, total=-19.50, time=245, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=245, action=4, reward=-1.00, total=-20.50, time=246, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=246, action=4, reward=-1.00, total=-21.50, time=247, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=247, action=4, reward=-1.00, total=-22.50, time=248, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=248, action=4, reward=-1.00, total=-23.50, time=249, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=249, action=4, reward=-1.00, total=-24.50, time=250, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=250, action=4, reward=-1.00, total=-25.50, time=251, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=251, action=4, reward=-1.00, total=-26.50, time=252, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=252, action=4, reward=-1.00, total=-27.50, time=253, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=253, action=4, reward=-1.00, total=-28.50, time=254, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=254, action=4, reward=-1.00, total=-29.50, time=255, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=255, action=4, reward=-1.00, total=-30.50, time=256, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=256, action=4, reward=-1.00, total=-31.50, time=257, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=257, action=4, reward=-1.00, total=-32.50, time=258, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=258, action=4, reward=-1.00, total=-33.50, time=259, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=259, action=4, reward=-1.00, total=-34.50, time=260, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=260, action=4, reward=-1.00, total=-35.50, time=261, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=261, action=4, reward=-1.00, total=-36.50, time=262, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=262, action=4, reward=-1.00, total=-37.50, time=263, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=263, action=4, reward=-1.00, total=-38.50, time=264, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=264, action=4, reward=-1.00, total=-39.50, time=265, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=265, action=4, reward=-1.00, total=-40.50, time=266, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=266, action=4, reward=-1.00, total=-41.50, time=267, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=267, action=4, reward=-1.00, total=-42.50, time=268, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=268, action=4, reward=-1.00, total=-43.50, time=269, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=269, action=4, reward=-1.00, total=-44.50, time=270, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=270, action=4, reward=-1.00, total=-45.50, time=271, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=271, action=4, reward=-1.00, total=-46.50, time=272, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=272, action=4, reward=-1.00, total=-47.50, time=273, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=273, action=4, reward=-1.00, total=-48.50, time=274, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=274, action=4, reward=-1.00, total=-49.50, time=275, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=275, action=4, reward=-1.00, total=-50.50, time=276, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=276, action=4, reward=-1.00, total=-51.50, time=277, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=277, action=4, reward=-1.00, total=-52.50, time=278, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=278, action=4, reward=-1.00, total=-53.50, time=279, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=279, action=4, reward=-1.00, total=-54.50, time=280, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=280, action=4, reward=-1.00, total=-55.50, time=281, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=281, action=4, reward=-1.00, total=-56.50, time=282, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=282, action=4, reward=-1.00, total=-57.50, time=283, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=283, action=4, reward=-1.00, total=-58.50, time=284, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=284, action=4, reward=-1.00, total=-59.50, time=285, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=285, action=4, reward=-1.00, total=-60.50, time=286, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=286, action=4, reward=-1.00, total=-61.50, time=287, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=287, action=4, reward=-1.00, total=-62.50, time=288, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=288, action=4, reward=-1.00, total=-63.50, time=289, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=289, action=4, reward=-1.00, total=-64.50, time=290, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=290, action=4, reward=-1.00, total=-65.50, time=291, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=291, action=4, reward=-1.00, total=-66.50, time=292, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=292, action=4, reward=-1.00, total=-67.50, time=293, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=293, action=4, reward=-1.00, total=-68.50, time=294, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=294, action=4, reward=-1.00, total=-69.50, time=295, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=295, action=4, reward=-1.00, total=-70.50, time=296, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=296, action=4, reward=-1.00, total=-71.50, time=297, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=297, action=4, reward=-1.00, total=-72.50, time=298, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=298, action=4, reward=-1.00, total=-73.50, time=299, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=299, action=4, reward=-1.00, total=-74.50, time=300, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=300, action=4, reward=-1.00, total=-75.50, time=301, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=301, action=4, reward=-1.00, total=-76.50, time=302, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=302, action=4, reward=-1.00, total=-77.50, time=303, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=303, action=4, reward=-1.00, total=-78.50, time=304, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=304, action=4, reward=-1.00, total=-79.50, time=305, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=305, action=4, reward=-1.00, total=-80.50, time=306, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=306, action=4, reward=-1.00, total=-81.50, time=307, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=307, action=4, reward=-1.00, total=-82.50, time=308, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=308, action=4, reward=-1.00, total=-83.50, time=309, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=309, action=4, reward=-1.00, total=-84.50, time=310, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=310, action=4, reward=-1.00, total=-85.50, time=311, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=311, action=4, reward=-1.00, total=-86.50, time=312, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=312, action=4, reward=-1.00, total=-87.50, time=313, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=313, action=4, reward=-1.00, total=-88.50, time=314, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=314, action=4, reward=-1.00, total=-89.50, time=315, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=315, action=4, reward=-1.00, total=-90.50, time=316, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=316, action=4, reward=-1.00, total=-91.50, time=317, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=317, action=4, reward=-1.00, total=-92.50, time=318, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=318, action=4, reward=-1.00, total=-93.50, time=319, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=319, action=4, reward=-1.00, total=-94.50, time=320, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=320, action=4, reward=-1.00, total=-95.50, time=321, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=321, action=4, reward=-1.00, total=-96.50, time=322, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=322, action=4, reward=-1.00, total=-97.50, time=323, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=323, action=4, reward=-1.00, total=-98.50, time=324, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=324, action=4, reward=-1.00, total=-99.50, time=325, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=325, action=4, reward=-1.00, total=-100.50, time=326, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=326, action=4, reward=-1.00, total=-101.50, time=327, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=327, action=4, reward=-1.00, total=-102.50, time=328, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=328, action=4, reward=-1.00, total=-103.50, time=329, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=329, action=4, reward=-1.00, total=-104.50, time=330, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=330, action=4, reward=-1.00, total=-105.50, time=331, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=331, action=4, reward=-1.00, total=-106.50, time=332, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=332, action=4, reward=-1.00, total=-107.50, time=333, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=333, action=4, reward=-1.00, total=-108.50, time=334, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=334, action=4, reward=-1.00, total=-109.50, time=335, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=335, action=4, reward=-1.00, total=-110.50, time=336, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=336, action=4, reward=-1.00, total=-111.50, time=337, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=337, action=4, reward=-1.00, total=-112.50, time=338, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=338, action=4, reward=-1.00, total=-113.50, time=339, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=339, action=4, reward=-1.00, total=-114.50, time=340, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=340, action=4, reward=-1.00, total=-115.50, time=341, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=341, action=4, reward=-1.00, total=-116.50, time=342, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=342, action=4, reward=-1.00, total=-117.50, time=343, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=343, action=4, reward=-1.00, total=-118.50, time=344, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=344, action=4, reward=-1.00, total=-119.50, time=345, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=345, action=4, reward=-1.00, total=-120.50, time=346, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=346, action=4, reward=-1.00, total=-121.50, time=347, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=347, action=4, reward=-1.00, total=-122.50, time=348, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=348, action=4, reward=-1.00, total=-123.50, time=349, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# t=349, action=4, reward=-1.00, total=-124.50, time=350, raw=0, P1=4, P2_inter=1, P2=0, backlog1=0, backlog2=0, busyM1=False, busyM2=False
# ...
# t=887, action=30, reward=-1.00, total=-583.36, time=888, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=888, action=30, reward=-1.00, total=-584.36, time=889, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=889, action=30, reward=-1.00, total=-585.36, time=890, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=890, action=30, reward=-1.00, total=-586.36, time=891, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=891, action=30, reward=-1.00, total=-587.36, time=892, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=892, action=30, reward=-1.00, total=-588.36, time=893, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=893, action=30, reward=-1.00, total=-589.36, time=894, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=894, action=30, reward=-1.00, total=-590.36, time=895, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=895, action=30, reward=-1.00, total=-591.36, time=896, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=896, action=30, reward=-1.00, total=-592.36, time=897, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=897, action=30, reward=-1.00, total=-593.36, time=898, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=898, action=30, reward=-1.00, total=-594.36, time=899, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=26, busyM1=False, busyM2=False
# t=899, action=30, reward=-1.92, total=-596.28, time=900, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=900, action=30, reward=-1.00, total=-597.28, time=901, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=901, action=30, reward=-1.00, total=-598.28, time=902, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=902, action=30, reward=-1.00, total=-599.28, time=903, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=903, action=30, reward=-1.00, total=-600.28, time=904, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=904, action=30, reward=-1.00, total=-601.28, time=905, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=905, action=30, reward=-1.00, total=-602.28, time=906, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=906, action=30, reward=-1.00, total=-603.28, time=907, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=907, action=30, reward=-1.00, total=-604.28, time=908, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=908, action=30, reward=-1.00, total=-605.28, time=909, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=909, action=30, reward=-1.00, total=-606.28, time=910, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=910, action=30, reward=-1.00, total=-607.28, time=911, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=911, action=30, reward=-1.00, total=-608.28, time=912, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=912, action=30, reward=-1.00, total=-609.28, time=913, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=913, action=30, reward=-1.00, total=-610.28, time=914, raw=0, P1=0, P2_inter=1, P2=0, backlog1=19, backlog2=27, busyM1=False, busyM2=False
# t=914, action=30, reward=-1.96, total=-612.24, time=915, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=915, action=30, reward=-1.00, total=-613.24, time=916, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=916, action=30, reward=-1.00, total=-614.24, time=917, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=917, action=30, reward=-1.00, total=-615.24, time=918, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=918, action=30, reward=-1.00, total=-616.24, time=919, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=919, action=30, reward=-1.00, total=-617.24, time=920, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=920, action=30, reward=-1.00, total=-618.24, time=921, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=921, action=30, reward=-1.00, total=-619.24, time=922, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=922, action=30, reward=-1.00, total=-620.24, time=923, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=923, action=30, reward=-1.00, total=-621.24, time=924, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=924, action=30, reward=-1.00, total=-622.24, time=925, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=925, action=30, reward=-1.00, total=-623.24, time=926, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=926, action=30, reward=-1.00, total=-624.24, time=927, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=927, action=30, reward=-1.00, total=-625.24, time=928, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=928, action=30, reward=-1.00, total=-626.24, time=929, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=28, busyM1=False, busyM2=False
# t=929, action=30, reward=-1.98, total=-628.22, time=930, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=930, action=30, reward=-1.00, total=-629.22, time=931, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=931, action=30, reward=-1.00, total=-630.22, time=932, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=932, action=30, reward=-1.00, total=-631.22, time=933, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=933, action=30, reward=-1.00, total=-632.22, time=934, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=934, action=30, reward=-1.00, total=-633.22, time=935, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=935, action=30, reward=-1.00, total=-634.22, time=936, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=936, action=30, reward=-1.00, total=-635.22, time=937, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=937, action=30, reward=-1.00, total=-636.22, time=938, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=938, action=30, reward=-1.00, total=-637.22, time=939, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=939, action=30, reward=-1.00, total=-638.22, time=940, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=940, action=30, reward=-1.00, total=-639.22, time=941, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=941, action=30, reward=-1.00, total=-640.22, time=942, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=942, action=30, reward=-1.00, total=-641.22, time=943, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=943, action=30, reward=-1.00, total=-642.22, time=944, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=29, busyM1=False, busyM2=False
# t=944, action=30, reward=-2.00, total=-644.22, time=945, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=945, action=30, reward=-1.00, total=-645.22, time=946, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=946, action=30, reward=-1.00, total=-646.22, time=947, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=947, action=30, reward=-1.00, total=-647.22, time=948, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=948, action=30, reward=-1.00, total=-648.22, time=949, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=949, action=30, reward=-1.00, total=-649.22, time=950, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=950, action=30, reward=-1.00, total=-650.22, time=951, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=951, action=30, reward=-1.00, total=-651.22, time=952, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=952, action=30, reward=-1.00, total=-652.22, time=953, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=953, action=30, reward=-1.00, total=-653.22, time=954, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=954, action=30, reward=-1.00, total=-654.22, time=955, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=955, action=30, reward=-1.00, total=-655.22, time=956, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=956, action=30, reward=-1.00, total=-656.22, time=957, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=957, action=30, reward=-1.00, total=-657.22, time=958, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=958, action=30, reward=-1.00, total=-658.22, time=959, raw=0, P1=0, P2_inter=1, P2=0, backlog1=20, backlog2=30, busyM1=False, busyM2=False
# t=959, action=30, reward=-2.06, total=-660.28, time=960, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=960, action=30, reward=-1.00, total=-661.28, time=961, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=961, action=30, reward=-1.00, total=-662.28, time=962, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=962, action=30, reward=-1.00, total=-663.28, time=963, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=963, action=30, reward=-1.00, total=-664.28, time=964, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=964, action=30, reward=-1.00, total=-665.28, time=965, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=965, action=30, reward=-1.00, total=-666.28, time=966, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=966, action=30, reward=-1.00, total=-667.28, time=967, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=967, action=30, reward=-1.00, total=-668.28, time=968, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=968, action=30, reward=-1.00, total=-669.28, time=969, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=969, action=30, reward=-1.00, total=-670.28, time=970, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=970, action=30, reward=-1.00, total=-671.28, time=971, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=971, action=30, reward=-1.00, total=-672.28, time=972, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=972, action=30, reward=-1.00, total=-673.28, time=973, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=973, action=30, reward=-1.00, total=-674.28, time=974, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=31, busyM1=False, busyM2=False
# t=974, action=30, reward=-2.08, total=-676.36, time=975, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=975, action=30, reward=-1.00, total=-677.36, time=976, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=976, action=30, reward=-1.00, total=-678.36, time=977, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=977, action=30, reward=-1.00, total=-679.36, time=978, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=978, action=30, reward=-1.00, total=-680.36, time=979, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=979, action=30, reward=-1.00, total=-681.36, time=980, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=980, action=30, reward=-1.00, total=-682.36, time=981, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=981, action=30, reward=-1.00, total=-683.36, time=982, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=982, action=30, reward=-1.00, total=-684.36, time=983, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=983, action=30, reward=-1.00, total=-685.36, time=984, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=984, action=30, reward=-1.00, total=-686.36, time=985, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=985, action=30, reward=-1.00, total=-687.36, time=986, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=986, action=30, reward=-1.00, total=-688.36, time=987, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=987, action=30, reward=-1.00, total=-689.36, time=988, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=988, action=30, reward=-1.00, total=-690.36, time=989, raw=0, P1=0, P2_inter=1, P2=0, backlog1=22, backlog2=32, busyM1=False, busyM2=False
# t=989, action=30, reward=-2.12, total=-692.48, time=990, raw=0, P1=0, P2_inter=1, P2=0, backlog1=23, backlog2=33, busyM1=False, busyM2=False
# t=990, action=30, reward=-1.00, total=-693.48, time=991, raw=0, P1=0, P2_inter=1, P2=0, backlog1=23, backlog2=33, busyM1=False, busyM2=False
# t=991, action=30, reward=-1.00, total=-694.48, time=992, raw=0, P1=0, P2_inter=1, P2=0, backlog1=23, backlog2=33, busyM1=False, busyM2=False
# t=992, action=30, reward=-1.00, total=-695.48, time=993, raw=0, P1=0, P2_inter=1, P2=0, backlog1=23, backlog2=33, busyM1=False, busyM2=False
# t=993, action=30, reward=-1.00, total=-696.48, time=994, raw=0, P1=0, P2_inter=1, P2=0, backlog1=23, backlog2=33, busyM1=False, busyM2=False
# t=994, action=30, reward=-1.00, total=-697.48, time=995, raw=0, P1=0, P2_inter=1, P2=0, backlog1=23, backlog2=33, busyM1=False, busyM2=False
# t=995, action=30, reward=-1.00, total=-698.48, time=996, raw=0, P1=0, P2_inter=1, P2=0, backlog1=23, backlog2=33, busyM1=False, busyM2=False
# t=996, action=30, reward=-1.00, total=-699.48, time=997, raw=0, P1=0, P2_inter=1, P2=0, backlog1=23, backlog2=33, busyM1=False, busyM2=False
# t=997, action=30, reward=-1.00, total=-700.48, time=998, raw=0, P1=0, P2_inter=1, P2=0, backlog1=23, backlog2=33, busyM1=False, busyM2=False
# t=998, action=30, reward=-1.00, total=-701.48, time=999, raw=0, P1=0, P2_inter=1, P2=0, backlog1=23, backlog2=33, busyM1=False, busyM2=False
# t=999, action=30, reward=-1.00, total=-702.48, time=1000, raw=0, P1=0, P2_inter=1, P2=0, backlog1=23, backlog2=33, busyM1=False, busyM2=False
